# %% [markdown]
# # Taylor Series
#
# Numerically test a Taylor Series expansion of
#  > $f(x)=c(1+x)^4$
#
# and compare the full function to the first-order Taylor-series approximation
#  > $f_1(x) = c(1+4x)$
#
# derived in the *A Note About Taylor Series* handed out on Canvas.
#
# We evaluate both functions for $c=1$ and values of $x$ ranging from 0 to 1 in steps of 0.01 and see where
# the fractional difference between the original formula and the first-order Taylor-series expansion form
#  > $\frac{\delta f(x)}{f(x)} = \frac{f(x)-f_1(x)}{f(x)}$
#
# becomes larger than 0.1%, 1%, and 10%.

# %%
# %matplotlib inline

import math
import numpy as np

x = np.linspace(0.0,1.0,101)

c = 1

fullForm = c*(1+x)**4
firstOrd = c*(1+4*x)
fracDiff = (fullForm-firstOrd)/fullForm

tenthPct = False
onePct = False
tenPct = False
print(' x     full   1stOr  df/f')
print('---------------------------')
for i in range(len(x)):
    if fracDiff[i] > 0.001 and not tenthPct:
        print('------- df/f > 0.1% -------')
        tenthPct = True
    if fracDiff[i] > 0.01 and not onePct:
        print('------- df/f > 1%   -------')
        onePct = True
    if fracDiff[i] > 0.1 and not tenPct:
        print('------- df/f > 10%  -------')
        tenPct = True
    print(f'{x[i]:.2f} {fullForm[i]:7.4f} {firstOrd[i]:7.4f} {fracDiff[i]:.4f}')
print('---------------------------')
# Out:
#  x     full   1stOr  df/f
# ---------------------------
# 0.00  1.0000  1.0000 0.0000
# 0.01  1.0406  1.0400 0.0006
# ------- df/f > 0.1% -------
# 0.02  1.0824  1.0800 0.0022
# 0.03  1.1255  1.1200 0.0049
# 0.04  1.1699  1.1600 0.0084
# ------- df/f > 1%   -------
# 0.05  1.2155  1.2000 0.0128
# 0.06  1.2625  1.2400 0.0178
# 0.07  1.3108  1.2800 0.0235
# 0.08  1.3605  1.3200 0.0298
# 0.09  1.4116  1.3600 0.0365
# 0.10  1.4641  1.4000 0.0438
# 0.11  1.5181  1.4400 0.0514
# 0.12  1.5735  1.4800 0.0594
# 0.13  1.6305  1.5200 0.0678
# 0.14  1.6890  1.5600 0.0764
# 0.15  1.7490  1.6000 0.0852
# 0.16  1.8106  1.6400 0.0942
# ------- df/f > 10%  -------
# 0.17  1.8739  1.6800 0.1035
# 0.18  1.9388  1.7200 0.1128
# 0.19  2.0053  1.7600 0.1223
# 0.20  2.0736  1.8000 0.1319
# 0.21  2.1436  1.8400 0.1416
# 0.22  2.2153  1.8800 0.1514
# 0.23  2.2889  1.9200 0.1612
# 0.24  2.3642  1.9600 0.1710
# 0.25  2.4414  2.0000 0.1808
# 0.26  2.5205  2.0400 0.1906
# 0.27  2.6014  2.0800 0.2004
# 0.28  2.6844  2.1200 0.2102
# 0.29  2.7692  2.1600 0.2200
# 0.30  2.8561  2.2000 0.2297
# 0.31  2.9450  2.2400 0.2394
# 0.32  3.0360  2.2800 0.2490
# 0.33  3.1290  2.3200 0.2586
# 0.34  3.2242  2.3600 0.2680
# 0.35  3.3215  2.4000 0.2774
# 0.36  3.4210  2.4400 0.2868
# 0.37  3.5228  2.4800 0.2960
# 0.38  3.6267  2.5200 0.3052
# 0.39  3.7330  2.5600 0.3142
# 0.40  3.8416  2.6000 0.3232
# 0.41  3.9525  2.6400 0.3321
# 0.42  4.0659  2.6800 0.3409
# 0.43  4.1816  2.7200 0.3495
# 0.44  4.2998  2.7600 0.3581
# 0.45  4.4205  2.8000 0.3666
# 0.46  4.5437  2.8400 0.3750
# 0.47  4.6695  2.8800 0.3832
# 0.48  4.7979  2.9200 0.3914
# 0.49  4.9288  2.9600 0.3995
# 0.50  5.0625  3.0000 0.4074
# 0.51  5.1989  3.0400 0.4153
# 0.52  5.3379  3.0800 0.4230
# 0.53  5.4798  3.1200 0.4306
# 0.54  5.6245  3.1600 0.4382
# 0.55  5.7720  3.2000 0.4456
# 0.56  5.9224  3.2400 0.4529
# 0.57  6.0757  3.2800 0.4601
# 0.58  6.2320  3.3200 0.4673
# 0.59  6.3913  3.3600 0.4743
# 0.60  6.5536  3.4000 0.4812
# 0.61  6.7190  3.4400 0.4880
# 0.62  6.8875  3.4800 0.4947
# 0.63  7.0591  3.5200 0.5014
# 0.64  7.2339  3.5600 0.5079
# 0.65  7.4120  3.6000 0.5143
# 0.66  7.5933  3.6400 0.5206
# 0.67  7.7780  3.6800 0.5269
# 0.68  7.9659  3.7200 0.5330
# 0.69  8.1573  3.7600 0.5391
# 0.70  8.3521  3.8000 0.5450
# 0.71  8.5504  3.8400 0.5509
# 0.72  8.7521  3.8800 0.5567
# 0.73  8.9575  3.9200 0.5624
# 0.74  9.1664  3.9600 0.5680
# 0.75  9.3789  4.0000 0.5735
# 0.76  9.5951  4.0400 0.5790
# 0.77  9.8151  4.0800 0.5843
# 0.78 10.0388  4.1200 0.5896
# 0.79 10.2663  4.1600 0.5948
# 0.80 10.4976  4.2000 0.5999
# 0.81 10.7328  4.2400 0.6050
# 0.82 10.9720  4.2800 0.6099
# 0.83 11.2151  4.3200 0.6148
# 0.84 11.4623  4.3600 0.6196
# 0.85 11.7135  4.4000 0.6244
# 0.86 11.9688  4.4400 0.6290
# 0.87 12.2283  4.4800 0.6336
# 0.88 12.4920  4.5200 0.6382
# 0.89 12.7599  4.5600 0.6426
# 0.90 13.0321  4.6000 0.6470
# 0.91 13.3086  4.6400 0.6514
# 0.92 13.5895  4.6800 0.6556
# 0.93 13.8749  4.7200 0.6598
# 0.94 14.1647  4.7600 0.6640
# 0.95 14.4590  4.8000 0.6680
# 0.96 14.7579  4.8400 0.6720
# 0.97 15.0614  4.8800 0.6760
# 0.98 15.3695  4.9200 0.6799
# 0.99 15.6824  4.9600 0.6837
# 1.00 16.0000  5.0000 0.6875
# ---------------------------

# %% [markdown]
# ## Graphical comparison
#
# Plot the full and first-order Taylor series approximation functions computed above in the top panel, then
# compute the fractional difference

# %%
import matplotlib.pyplot as plt

fig,ax = plt.subplots()

plt.xlim(0,1.0)
plt.plot(x,fullForm,'-',color='black',lw=1,label=r'Full Form $f(x)=(1+x)^4$')
plt.plot(x,firstOrd,'--',color='blue',lw=1,label=r'1st Order $f_1(x)=(1+4x)$')
plt.xlabel('x')
plt.ylabel('$f(x)$ and $f_1(x)$')
plt.legend()
plt.show()

fig,ax = plt.subplots()

plt.xlim(0,1.0)
plt.plot(x,fracDiff,'-',color='black',lw=1)
plt.xlabel('x')
plt.ylabel(r'fractional difference $\delta f(x) / f(x)$')
plt.hlines([0.01,0.1],0.0,1.0,lw=0.5,ls=[':'],colors=['black'])
plt.text(1.0,0.01,' fracDiff=1%',va='center')
plt.text(1.0,0.1,' fracDiff=10%',va='center')

plt.show()
